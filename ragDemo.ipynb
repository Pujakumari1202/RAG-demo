# %%
print("OK")
# Out:
# OK

# %%
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_openai
# !pip install python-dotenv
# !pip install streamlit
# !pip install langchain_experimental
# !pip install sentence-transformers
# !pip install langchain_chroma
# !pip install langchainhub
# !pip install unstructured
# Out:
# Requirement already satisfied: langchain in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.3.7)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: langchain_community in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.3.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (0.3.7)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (0.3.15)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain_community) (0.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain_community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain_community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<2.0.36,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain_community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Collecting langchain_openai
#   Using cached langchain_openai-0.2.6-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_openai) (0.3.15)
# Collecting openai<2.0.0,>=1.54.0 (from langchain_openai)
#   Using cached openai-1.54.3-py3-none-any.whl.metadata (24 kB)
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Using cached tiktoken-0.8.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (0.1.142)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain_openai) (4.6.2.post1)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.54.0->langchain_openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain_openai) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.54.0->langchain_openai)
#   Using cached jiter-0.7.0-cp312-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from openai<2.0.0,>=1.54.0->langchain_openai) (4.67.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain_openai) (3.10)
# Requirement already satisfied: certifi in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain_openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain_openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain_openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_openai) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.15->langchain_openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.15->langchain_openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.15->langchain_openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (2.2.3)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.54.0->langchain_openai) (0.4.6)
# Using cached langchain_openai-0.2.6-py3-none-any.whl (50 kB)
# Using cached openai-1.54.3-py3-none-any.whl (389 kB)
# Using cached tiktoken-0.8.0-cp312-cp312-win_amd64.whl (883 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.7.0-cp312-none-win_amd64.whl (199 kB)
# Installing collected packages: jiter, distro, tiktoken, openai, langchain_openai
# Successfully installed distro-1.9.0 jiter-0.7.0 langchain_openai-0.2.6 openai-1.54.3 tiktoken-0.8.0
# Requirement already satisfied: python-dotenv in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (1.0.1)
# Collecting streamlit
#   Using cached streamlit-1.40.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Using cached altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (24.1)
# Collecting pandas<3,>=1.4.0 (from streamlit)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pillow<12,>=7.1.0 (from streamlit)
#   Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Using cached protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Using cached pyarrow-18.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (2.32.3)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (9.0.0)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from streamlit) (6.4.1)
# Collecting watchdog<6,>=2.1.5 (from streamlit)
#   Using cached watchdog-5.0.3-py3-none-win_amd64.whl.metadata (41 kB)
# Collecting jinja2 (from altair<6,>=4.0->streamlit)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit)
#   Using cached narwhals-1.13.3-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Collecting pytz>=2020.1 (from pandas<3,>=1.4.0->streamlit)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3,>=1.4.0->streamlit)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->altair<6,>=4.0->streamlit)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit)
#   Using cached rpds_py-0.21.0-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Using cached streamlit-1.40.0-py2.py3-none-any.whl (8.6 MB)
# Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pillow-11.0.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached protobuf-5.28.3-cp310-abi3-win_amd64.whl (431 kB)
# Using cached pyarrow-18.0.0-cp312-cp312-win_amd64.whl (25.1 MB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached watchdog-5.0.3-py3-none-win_amd64.whl (79 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached narwhals-1.13.3-py3-none-any.whl (201 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rpds_py-0.21.0-cp312-none-win_amd64.whl (220 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: pytz, watchdog, tzdata, toml, smmap, rpds-py, pyarrow, protobuf, pillow, narwhals, mdurl, MarkupSafe, cachetools, blinker, referencing, pandas, markdown-it-py, jinja2, gitdb, rich, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed MarkupSafe-3.0.2 altair-5.4.1 blinker-1.9.0 cachetools-5.5.0 gitdb-4.0.11 gitpython-3.1.43 jinja2-3.1.4 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.13.3 pandas-2.2.3 pillow-11.0.0 protobuf-5.28.3 pyarrow-18.0.0 pydeck-0.9.1 pytz-2024.2 referencing-0.35.1 rich-13.9.4 rpds-py-0.21.0 smmap-5.0.1 streamlit-1.40.0 toml-0.10.2 tzdata-2024.2 watchdog-5.0.3
# Collecting langchain_experimental
#   Using cached langchain_experimental-0.3.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_experimental) (0.3.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_experimental) (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.7)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_experimental) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_experimental) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain_experimental) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.15->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.3.15->langchain_experimental) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<2.0.36,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.1.1)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.2.0)
# Using cached langchain_experimental-0.3.3-py3-none-any.whl (208 kB)
# Installing collected packages: langchain_experimental
# Successfully installed langchain_experimental-0.3.3
# Collecting sentence-transformers
#   Using cached sentence_transformers-3.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.46.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: tqdm in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (4.67.0)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.5.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: scipy in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from sentence-transformers) (1.13.1)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence-transformers) (11.0.0)
# Collecting filelock (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Collecting networkx (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Collecting sympy==1.13.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.4.5-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Using cached sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
# Using cached huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Using cached torch-2.5.1-cp312-cp312-win_amd64.whl (203.0 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached transformers-4.46.2-py3-none-any.whl (10.0 MB)
# Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Using cached safetensors-0.4.5-cp312-none-win_amd64.whl (286 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl (2.4 MB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, safetensors, networkx, fsspec, filelock, torch, scikit-learn, huggingface-hub, tokenizers, transformers, sentence-transformers
# Successfully installed filelock-3.16.1 fsspec-2024.10.0 huggingface-hub-0.26.2 mpmath-1.3.0 networkx-3.4.2 safetensors-0.4.5 scikit-learn-1.5.2 sentence-transformers-3.2.1 sympy-1.13.1 threadpoolctl-3.5.0 tokenizers-0.20.3 torch-2.5.1 transformers-4.46.2
# Collecting langchain_chroma
#   Using cached langchain_chroma-0.1.4-py3-none-any.whl.metadata (1.6 kB)
# Collecting chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 (from langchain_chroma)
#   Using cached chromadb-0.5.18-py3-none-any.whl.metadata (6.8 kB)
# Collecting fastapi<1,>=0.95.2 (from langchain_chroma)
#   Using cached fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.1.40 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_chroma) (0.3.15)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain_chroma) (1.26.4)
# Collecting build>=1.0.3 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2.9.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.20.3)
# Collecting pypika>=0.48.9 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (4.67.0)
# Collecting overrides>=7.3.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached typer-0.13.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (13.9.4)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi<1,>=0.95.2->langchain_chroma)
#   Using cached starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4,>=0.1.40->langchain_chroma) (1.33)
# ...
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (5.5.0)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (3.4.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain_chroma)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached langchain_chroma-0.1.4-py3-none-any.whl (10 kB)
# Using cached chromadb-0.5.18-py3-none-any.whl (615 kB)
# Using cached fastapi-0.115.4-py3-none-any.whl (94 kB)
# Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl (39 kB)
# Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
# Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.7.0-py2.py3-none-any.whl (54 kB)
# Using cached starlette-0.41.2-py3-none-any.whl (73 kB)
# Using cached typer-0.13.0-py3-none-any.whl (44 kB)
# Using cached uvicorn-0.32.0-py3-none-any.whl (63 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl (277 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-14.0-cp312-cp312-win_amd64.whl (162 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)
# Collecting langchainhub
#   Using cached langchainhub-0.1.21-py3-none-any.whl.metadata (659 bytes)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchainhub) (24.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchainhub) (2.32.3)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Using cached types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchainhub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchainhub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchainhub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchainhub) (2024.8.30)
# Using cached langchainhub-0.1.21-py3-none-any.whl (5.2 kB)
# Using cached types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Installing collected packages: types-requests, langchainhub
# Successfully installed langchainhub-0.1.21 types-requests-2.32.0.20241016
# Requirement already satisfied: unstructured in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.16.5)
# Requirement already satisfied: chardet in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2.14.0)
# Requirement already satisfied: dataclasses-json in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2024.10.22)
# Requirement already satisfied: langdetect in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (3.10.1)
# Requirement already satisfied: backoff in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.27.0)
# Requirement already satisfied: wrapt in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (4.67.0)
# Requirement already satisfied: psutil in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.0.1)
# Requirement already satisfied: html5lib in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: olefile in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: cryptography>=3.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (43.0.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: pypdf>=4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (5.1.0)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)

# %%
# !pip install sentence_transformers
# !pip -q install langchain tiktoken chromadb pypdf transformers
# !pip -q install accelerate bitsandbytes sentencepiece Xformers
# Out:
# Requirement already satisfied: sentence_transformers in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence_transformers) (4.46.2)
# Requirement already satisfied: tqdm in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence_transformers) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence_transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence_transformers) (0.26.2)
# Requirement already satisfied: Pillow in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: filelock in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: networkx in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence_transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\PUJA KUMARI\\AppData\\Local\\Temp\\pip-install-zuqctfid\\xformers_cf5e11c63f314d618d01f8cbfef444d4\\third_party\\flash-attention\\csrc\\composable_kernel\\client_example\\24_grouped_conv_activation\\grouped_convnd_bwd_data_bilinear\\grouped_conv_bwd_data_bilinear_residual_fp16.cpp'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.3.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<2.0.36,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (0.3.7)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (0.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<2.0.36,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
# !pip install unstructured
# Out:
# Requirement already satisfied: unstructured in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.16.5)
# Requirement already satisfied: chardet in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2.14.0)
# Requirement already satisfied: dataclasses-json in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2024.10.22)
# Requirement already satisfied: langdetect in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy<2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (3.10.1)
# Requirement already satisfied: backoff in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.27.0)
# Requirement already satisfied: wrapt in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (4.67.0)
# Requirement already satisfied: psutil in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (5.9.0)
# Requirement already satisfied: python-oxmsg in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (0.0.1)
# Requirement already satisfied: html5lib in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: olefile in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: cryptography>=3.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (43.0.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: pypdf>=4.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (5.1.0)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)

# %%
urls = ['https://www.victoriaonmove.com.au/local-removalists.html','https://victoriaonmove.com.au/index.html','https://victoriaonmove.com.au/contact.html']
loader = UnstructuredURLLoader(urls=urls)
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content='Loading...\n\nLOCAL REMOVALS\n\nYour trusted partner in seamless moving and packing solutions!\n\nGoogle Rating\n\n5 stars, 111 reviews\n\nRequst A call for You:\n\nLocal removal services via "Victoria on move"\n\nVictoria on Move is your trusted local moving company in Melbourne, specializing in seamless relocation services. As experienced furniture movers and relocation experts, we provide top-notch packing and moving services tailored to your needs. Whether you\'re moving across town or relocating interstate, our professional movers ensure a stress-free experience. Count on Victoria on Move for reliable removal services, making us the preferred choice among local movers in Melbourne. Discover why we\'re recognized for our commitment to quality and customer satisfaction.\n\nApartment Moving\n\nEfficient and careful relocation services tailored for apartments of all sizes, ensuring smooth transitions to your new home.\n\nVilla Moving\n\nComprehensive moving solutions for large residences and villas, handling valuable possessions with utmost care and precision.\n\nHousehold Moving\n\nFull-service moving options for households, including packing, loading, transportation, and unpacking services to simplify your move.\n\nOffice Moving\n\nSpecialized expertise in office relocations, minimizing downtime and ensuring your business operations continue seamlessly.\n\nFurniture Moving\n\nExperienced in handling furniture of all sizes and types, ensuring safe transport and setup in your new location.\n\nPacking and Unpacking Services\n\nOptional packing and unpacking services available to save you time and effort, using high-quality packing materials.\n\nCustomized Moving Plans\n\nTailored moving plans to fit your specific requirements and schedule, providing personalized service and peace of mind.\n\nProfessional Team\n\nExperienced and courteous moving professionals dedicated to delivering exceptional service and customer satisfaction throughout the entire moving process.\n\nFind removalists travelling to or from Melbourne\n\nFrom Melbourne\n\nTo Melbourne\n\nMoving from Ballarat to MelbourneMoving from Bendigo to MelbourneMoving from Geelong to MelbourneMoving from Melton to MelbourneMoving from Mildura to MelbourneMoving from Mooroopna to MelbourneMoving from Shepparton to MelbourneMoving from Sunbury to MelbourneMoving from Traralgon to MelbourneMoving from Warrnambool to MelbourneMoving from Wodonga to Melbourne\n\nMoving from Melbourne to BallaratMoving from Melbourne to BendigoMoving from Melbourne to GeelongMoving from Melbourne to MeltonMoving from Melbourne to MilduraMoving from Melbourne to MooroopnaMoving from Melbourne to SheppartonMoving from Melbourne to SunburyMoving from Melbourne to TraralgonMoving from Melbourne to WarrnamboolMoving from Melbourne to Wodonga\n\nLooking for interstate removalists Melbourne? We can also assist with interstate moves to or from Melbourne.\n\nGet In Touch\n\nWollert Victoria\n\n0404922328\n\nvictoriaonmove07@gmail.com\n\nQuick Links\n\nAbout Us Contact Us Our Services Terms & Condition\n\nPhoto Gallery\n\nCheck us out on Google!\n\n© Victoria On Move 2024, All Right Reserved. Designed By HTML Codex\n\nHome'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content="Loading...\n\nRelocate with confidence\n\nYour trusted partner in seamless moving and packing solutions!\n\nGoogle Rating\n\n5 stars, 111 reviews\n\nRequst A call for You:\n\nExplore Our Fleet\n\nVehicles Tailored for Your Moving Needs\n\nSmall Truck\n\nWith 2 Mover\n\nFrom $130/hr\n\n4.5 ton 20 cubic Our Small Truck can manage a student apartment, small office .\n\nMedium Truck\n\nWith 2 Mover\n\nFrom $145 p/hr\n\n6 ton 30-35 cubic\n\nOur Medium trucks can manage 2-3 bedroom with single lounge outdoor boxes and miscellaneous.\n\nLarge Truck\n\nWith 2 Mover\n\nFrom $155 p/hr\n\n8 ton 40 cubic Our Large trucks can handle 3-4 bedrooms with double lounge outdoor boxes and miscellaneous.\n\nX-Large Truck\n\nWith 2 Mover\n\nFrom $165 p/hr\n\n4.5 ton 20 cubic (10 ton or 50 cubic meter) Our X-Large trucks can handle 3-4 bedrooms double lounge outdoor miscellaneous items.\n\nOUR SERVICE\n\nWE OFFER QUICK & POWERFUL LOGISTICS SOLUTION\n\nFURNITURE REMOVALS:\n\nWe are the furniture removals specialists in Victoria. Our Teams are experienced and comes with Furniture moving equipments like- Trolleys. Blankets, Loading Ramps.\n\nINSURANCE:\n\nVictoria On Move Pvt Ltd. look after your goods arrive safely at your destination. We have Transit and Public liability insurance. Transit insurance covers loading and unloading from vehicle , and Road accident cover.\n\n1 BED HOME:\n\n1 Bed, Mattress, Tall Boy, Bedside, Refrigerator, Washing Machine, Some Boxes.\n\n2 BED HOME:\n\n2 Beds, Mattress, Tall Boy, Bedside, Refrigerator, Washing Machine,Dresser, Barbeque, Some Boxes, Loose stuff.\n\nBig HOME:\n\n4-5 Bed Room, Double Lounge, Mattress, Tall Boy, Bedside, Refrigerator, Washing Machine,Dresser, Barbeque, Some Boxes,Furniture, Loose stuff. Get a Quote\n\nInterstate Removalists:\n\nSeamless Relocation Across State Lines\n\nMelbourne to Sydney Removalists\n\nBook Now\n\nMelbourne to Brisbane Removalists\n\nBook Now\n\nMelbourne to Adelaide Removalists\n\nBook Now\n\nMelbourne to Canberra Removalists\n\nBook Now\n\nOUR MOVING WORK & ETHICS\n\nMoving house furniture is an art that comes with experience and a steadfast commitment to our customers' needs. It's a challenging industry, and not everyone survives for long without the expertise and dedication that we bring to every job. Our long history as Removalists in Melbourne is a testament to our sincerity and hard work.\n\nUnlike some other moving companies, we value the trust our customers place in us. Our customer reviews on Google are genuine, and we never manipulate them. We trust in our quality and experience and believe in our destiny to provide top-notch moving and packing services to our clients.\n\nContact Us\n\nOur Clients Say!\n\nDiscover firsthand experiences from our valued clients through their heartfelt testimonials. From seamless moves to exceptional service, our customers share how we've made their relocation journey stress-free and rewarding. Explore their stories and see why they trust us with their moves time and again.\n\nGet In Touch\n\nWollert Victoria\n\n0404922328\n\nvictoriaonmove07@gmail.com\n\nQuick Links\n\nAbout Us Contact Us Our Services Terms & Condition\n\nPhoto Gallery\n\nCheck us out on Google!\n\n© Victoria On Move 2024, All Right Reserved. Designed By HTML Codex\n\nHome"),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/contact.html'}, page_content='Loading...\n\nContact Us\n\nYou can contact us any way that is convenient for you. We are available 24/7 via fax or email. You can also use a quick contact form below or visit our office personally. We would be happy to answer your questions.\n\nWollert Victoria\n\nvictoriaonmove07@gmail.com\n\n0404922328\n\nFind removalists travelling interstate to or from Sydney\n\nFrom Sydney\n\nTo Sydney\n\nMoving from Adelaide to SydneyMoving from Ballarat to SydneyMoving from Bendigo to SydneyMoving from Brisbane to SydneyMoving from Cairns to SydneyMoving from Canberra to SydneyMoving from Darwin to SydneyMoving from Geelong to SydneyMoving from Gold Coast to SydneyMoving from Hobart to SydneyMoving from Melbourne to SydneyMoving from Perth to SydneyMoving from Tasmania to Sydney\n\nMoving from Sydney to AdelaideMoving from Sydney to BallaratMoving from Sydney to BendigoMoving from Sydney to BrisbaneMoving from Sydney to BunburyMoving from Sydney to BundabergMoving from Sydney to CairnsMoving from Sydney to CanberraMoving from Sydney to DarwinMoving from Sydney to DevonportMoving from Sydney to Fraser CoastMoving from Sydney to GeelongMoving from Sydney to GeraldtonMoving from Sydney to GladstoneMoving from Sydney to Gold CoastMoving from Sydney to Hervey BayMoving from Sydney to HobartMoving from Sydney to LauncestonMoving from Sydney to MackayMoving from Sydney to MandurahMoving from Sydney to MelbourneMoving from Sydney to MeltonMoving from Sydney to PerthMoving from Sydney to RockhamptonMoving from Sydney to SheppartonMoving from Sydney to Sunshine CoastMoving from Sydney to TasmaniaMoving from Sydney to ToowoombaMoving from Sydney to TownsvilleMoving from Sydney to TraralgonMoving from Sydney to Warrnambool\n\nIf you are in need of local removalists services in Sydney we can also help with professional movers for local moves.\n\nGet In Touch\n\nWollert Victoria\n\n0404922328\n\nvictoriaonmove07@gmail.com\n\nQuick Links\n\nAbout Us Contact Us Our Services Terms & Condition\n\nPhoto Gallery\n\nCheck us out on Google!\n\n© Victoria On Move 2024, All Right Reserved. Designed By HTML Codex\n\nHome')]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# split data
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
docs = text_splitter.split_documents(data)


print("Total number of documents: ",len(docs))
# Out:
# Total number of documents:  11

# %%
docs[0]
# Out:
# Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content='Loading...\n\nLOCAL REMOVALS\n\nYour trusted partner in seamless moving and packing solutions!\n\nGoogle Rating\n\n5 stars, 111 reviews\n\nRequst A call for You:\n\nLocal removal services via "Victoria on move"\n\nVictoria on Move is your trusted local moving company in Melbourne, specializing in seamless relocation services. As experienced furniture movers and relocation experts, we provide top-notch packing and moving services tailored to your needs. Whether you\'re moving across town or relocating interstate, our professional movers ensure a stress-free experience. Count on Victoria on Move for reliable removal services, making us the preferred choice among local movers in Melbourne. Discover why we\'re recognized for our commitment to quality and customer satisfaction.\n\nApartment Moving\n\nEfficient and careful relocation services tailored for apartments of all sizes, ensuring smooth transitions to your new home.\n\nVilla Moving')

# %%
# !pip install langchain chromadb
# !pip install --upgrade langchain chromadb
# Out:
# Requirement already satisfied: langchain in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.3.7)
# Collecting chromadb
#   Using cached chromadb-0.5.18-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (9.0.0)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (0.20.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (4.67.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.13.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: protobuf in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.3)
# Requirement already satisfied: sympy in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl.metadata (6.2 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from opentelemetry-instrumentation==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-14.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached chromadb-0.5.18-py3-none-any.whl (615 kB)
# Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached fastapi-0.115.4-py3-none-any.whl (94 kB)
# Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl (39 kB)
# Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
# Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.7.0-py2.py3-none-any.whl (54 kB)
# Using cached typer-0.13.0-py3-none-any.whl (44 kB)
# Using cached uvicorn-0.32.0-py3-none-any.whl (63 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.41.2-py3-none-any.whl (73 kB)
# Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl (277 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-14.0-cp312-cp312-win_amd64.whl (162 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)
# Requirement already satisfied: langchain in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.3.7)
# Collecting chromadb
#   Using cached chromadb-0.5.18-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (9.0.0)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (0.20.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (4.67.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.13.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: protobuf in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.3)
# Requirement already satisfied: sympy in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl.metadata (6.2 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from opentelemetry-instrumentation==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-14.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached chromadb-0.5.18-py3-none-any.whl (615 kB)
# Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached fastapi-0.115.4-py3-none-any.whl (94 kB)
# Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl (39 kB)
# Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
# Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.7.0-py2.py3-none-any.whl (54 kB)
# Using cached typer-0.13.0-py3-none-any.whl (44 kB)
# Using cached uvicorn-0.32.0-py3-none-any.whl (63 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.41.2-py3-none-any.whl (73 kB)
# Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl (277 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-14.0-cp312-cp312-win_amd64.whl (162 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)

# %%
# !pip install langchain chromadb openai
# Out:
# Requirement already satisfied: langchain in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (0.3.7)
# Collecting chromadb
#   Using cached chromadb-0.5.18-py3-none-any.whl.metadata (6.8 kB)
# Collecting openai
#   Using cached openai-1.54.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (0.1.142)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain) (9.0.0)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.4-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.28.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (4.67.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl.metadata (9.9 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.13.0-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from chromadb) (0.27.2)
# Collecting rich>=10.11.0 (from chromadb)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from openai) (4.6.2.post1)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Using cached jiter-0.7.0-cp312-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.1)
# Requirement already satisfied: idna>=2.8 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: packaging>=19.1 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.41.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langchain-core<0.4.0,>=0.3.15->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.28.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl.metadata (6.2 kB)
# Collecting opentelemetry-semantic-conventions==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.49b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\puja kumari\appdata\roaming\python\python312\site-packages (from opentelemetry-instrumentation==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.49b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Using cached huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-14.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: zipp>=3.20 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.20.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain) (3.0.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\puja kumari\anaconda3\envs\rag\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached chromadb-0.5.18-py3-none-any.whl (615 kB)
# Using cached openai-1.54.3-py3-none-any.whl (389 kB)
# Using cached bcrypt-4.2.0-cp39-abi3-win_amd64.whl (151 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached fastapi-0.115.4-py3-none-any.whl (94 kB)
# Using cached grpcio-1.67.1-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached jiter-0.7.0-cp312-none-win_amd64.whl (199 kB)
# Using cached kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
# Using cached mmh3-5.0.1-cp312-cp312-win_amd64.whl (39 kB)
# Using cached onnxruntime-1.20.0-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_api-1.28.1-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.28.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.28.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.49b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.49b1-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.49b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.49b1-py3-none-any.whl (159 kB)
# Using cached opentelemetry_util_http-0.49b1-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.28.1-py3-none-any.whl (118 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.7.0-py2.py3-none-any.whl (54 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl (2.4 MB)
# Using cached typer-0.13.0-py3-none-any.whl (44 kB)
# Using cached uvicorn-0.32.0-py3-none-any.whl (63 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached protobuf-5.28.3-cp310-abi3-win_amd64.whl (431 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.41.2-py3-none-any.whl (73 kB)
# Using cached watchfiles-0.24.0-cp312-none-win_amd64.whl (277 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-14.0-cp312-cp312-win_amd64.whl (162 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from langchain_chroma import Chroma
#       2 from langchain_openai import OpenAIEmbeddings
#       3 from langchain_openai import OpenAI
#
# ModuleNotFoundError: No module named 'langchain_chroma'

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
vectorstore = Chroma.from_documents(documents=docs, embedding=OpenAIEmbeddings())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 vectorstore = Chroma.from_documents(documents=docs, embedding=OpenAIEmbeddings())
#
# NameError: name 'Chroma' is not defined

# %%
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
retrieved_docs = retriever.invoke("What kind of services they provide?")

# %%
len(retrieved_docs)

# %%
retrieved_docs

# %%
print(retrieved_docs[0].page_content)

# %%
llm = OpenAI(temperature=0.4, max_tokens=500)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "What kind of services they provide?"})
print(response["answer"])
